# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("[SUCCESS] All required libraries imported successfully!")
# Out:
# [SUCCESS] All required libraries imported successfully!

# %%
# 1. Load the three CSV files
df_dawlance = pd.read_csv('dawlance_mega_t10_200_pages_reviews.csv')
df_haier_pearl = pd.read_csv('haier_pearl_black_hsu18hfp_reviews.csv')
df_haier_lf = pd.read_csv('haier_reviews.csv')

# Add Product Labels
df_dawlance['product'] = 'Dawlance Mega T+ 10'
df_haier_pearl['product'] = 'Haier Pearl Black (HSU-18HFP)'
df_haier_lf['product'] = 'Haier LF Inverter (HSU-19LF)'

# Combine datasets into a master dataframe
df = pd.concat([df_dawlance, df_haier_pearl, df_haier_lf], ignore_index=True)

print("--- DATASET SUMMARY ---")
print("\nReviews Breakdown by Product:")
print(df['product'].value_counts())
df.head(5)
# Out:
# --- DATASET SUMMARY ---
#
# Reviews Breakdown by Product:
# product
# Dawlance Mega T+ 10              799
# Haier LF Inverter (HSU-19LF)      49
# Haier Pearl Black (HSU-18HFP)     18
# Name: count, dtype: int64
#     id  page       user  date  \
# 0  1.0   1.0  Anonymous   NaN
# 1  2.0   1.0  Anonymous   NaN
# 2  3.0   1.0  Anonymous   NaN
# 3  4.0   2.0  Anonymous   NaN
# 4  5.0   2.0  Anonymous   NaN
#
#                                               review              product
# 0  #11. 11 best quality air conditioner dawlance ...  Dawlance Mega T+ 10
# 1  #11.11 what a product in this price with longe...  Dawlance Mega T+ 10
# 2  bohat he ganda AC full waste of money and elec...  Dawlance Mega T+ 10
# 3  new review update   Alhamdulillah 5th june ko ...  Dawlance Mega T+ 10
# 4  Amazing product from dawlance, timely delivere...  Dawlance Mega T+ 10
